# %%
import pandas as pd
from pathlib import Path
import datetime as dt

# %%
df = pd.read_excel("index_to_clean.xlsx")

# %%
df.shape
# Out:
# (914, 4)

# %%
df.dtypes
# Out:
# date              datetime64[us]
# order_no                   int64
# party_name                   str
# contact_number               str
# dtype: object

# %%
# CURRENT_FOLDER = Path.cwd().resolve()  
# OUTPUT_FILE = CURRENT_FOLDER / "index_to_clean.xlsx"

# df.to_excel(OUTPUT_FILE.as_posix(), index=False)
